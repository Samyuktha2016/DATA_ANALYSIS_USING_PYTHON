# %% [markdown]
# PANDAS

# %%
#importing pandas
import pandas as pd  #IMPORTING PANDAS

# %%
#pandas
#Seies syntax--->pd.Series(col,index)
a=["Jwalitha",'ramya','durga','jahnavi','lahari','sunny','dhanush']
r=pd.Series(a, index=[67,43,44,89,34,45,23])   #pd.series   series creates as rows columns series s should be capital (col,index)
print(r)
# Out:
# 67    Jwalitha
# 43       ramya
# 44       durga
# 89     jahnavi
# 34      lahari
# 45       sunny
# 23     dhanush
# dtype: object

# %%
#seperately taking index
a=["Jwalitha",'ramya','durga','jahnavi','lahari','sunny','dhanush']
index=([67,43,44,89,34,45,23])
r=pd.Series(a,index)
print(r)
# Out:
# 67    Jwalitha
# 43       ramya
# 44       durga
# 89     jahnavi
# 34      lahari
# 45       sunny
# 23     dhanush
# dtype: object

# %%
#printing the col and index
col=["joe","Raj"]
ind=[37,77]
r=pd.Series(col,ind)
print(r)
# Out:
# 37    joe
# 77    Raj
# dtype: object

# %%
#loading csv
dia=pd.read_csv("/content/diabetcsv.csv")   #csv files
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grad=pd.read_csv("/content/grades_withnulls.txt",sep=",")   #for text files
grad
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
grade=pd.read_csv("/content/demodt.txt",sep=",")  #for text files
grade
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxcl=pd.read_excel("/content/diabetes.xlsx") #for excels
diaxcl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diadxcls=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora") #for excel which contains two sheets
diadxcls
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diaxcl.describe()   #for describing diabetics of excel file
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
#shape
grade=pd.read_csv("/content/demodt.txt",sep=",")
print(grade.shape)  #get the no of rows and columns
print(grade.shape[0])  #get the no of rows
print(grade.shape[1])  #get the no of columns
# Out:
# (26, 5)
# 26
# 5

# %%
grade.describe()
# Out:
#         Literacy  Cleanliness  Crime_Rate       Good
# count  26.000000    26.000000   26.000000  26.000000
# mean   75.269231    77.038462   52.307692   0.423077
# std    12.078270     8.879103    6.208183   0.503831
# min    55.000000    63.000000   41.000000   0.000000
# 25%    67.250000    69.250000   47.250000   0.000000
# 50%    75.500000    77.500000   52.000000   0.000000
# 75%    84.750000    83.750000   57.000000   1.000000
# max    94.000000    92.000000   63.000000   1.000000

# %%
df=pd.read_csv("/content/grades_withnulls.csv",sep=",")
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv",sep=",")
df.dropna()   #changes are not reflected
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv",sep=",")
df.dropna(inplace=True)   #changes are reflected
df      #to save the changes,create new dataframe or give inplce=True
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1=pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace=True)
df1
#to save the changes,create new dataframe or give inplce=True
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
mdf=df2.dropna()
mdf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df.fillna(555)
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.dropna()
#to save the changes,create new dataframe
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv",sep=",")
df2.fillna(555,inplace=True)   #fills the given values into the null values in data frame
df2                            #reflects the chnages in the original data frame
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
print(df.isnull())  #for checking null values
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
mydf=pd.read_csv("/content/grades_withnulls.csv",sep=",")
mv=mydf['SEM1'].mean()    #calculates the mean of sem1 marks
print(mv)
mydf.fillna(mv,inplace=True)       #replaces the null places with mean and changes are reflected
mydf
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#iloc = integer location,index
#loc = field names, index
#dfname.loc[index]--->rows
#dfname.loc[st:stop]--->range of rows
#dfname.loc[r_ind,col_name]--->rows&col
mydf.loc[0]   #first record !
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
mydf.loc[0:5]  #first five records!
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1

# %%
mydf.loc[8:14]  #range of records!
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 8     Jess        K  8.992857   9.1   9.9    A+       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 11    Maya        N  7.700000   8.0   7.1     B       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 14    Riya        M  9.300000   9.9  10.0     A       1

# %%
mydf.loc[5:7,"SEM1"]   #five to seven  records !
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
mydf.iloc[10:12,0:2]    #both rows and columns --->index  # both rows and columns----index it only accepts indexes rows and ciolunns also but loc take all
# Out:
#     Names Initials
# 10  Kiran        V
# 11   Maya        N

# %%
mydf[mydf.Grade== 'A']
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 2   Kissan        V  9.900000   9.8  10.0     A       0
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 6   Hassan        V  9.900000   9.0   9.2     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 14    Riya        M  9.300000   9.9  10.0     A       1
# 15    Sana        V  9.900000   9.3   9.2     A       0

# %%
mydf[mydf.SEM2==9.1]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 4     Jeen        K  9.800000   9.1   9.9    A+       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 8     Jess        K  8.992857   9.1   9.9    A+       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
#print the records who scored 9.3 in sem3
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1

# %%
mydf2.loc[mydf2['SEM1']>9.8,['Names']]    #k=loc[index,columns]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 8     Jess
# 9   Rajini
# 10   Kiran
# 15    Sana

# %%
mydf.loc[mydf['SEM1']>9.8,['Names']]    #k=loc[index,columns]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
#print the grades  of students who scored more than 9.7 in sem3
mydf.loc[mydf.SEM3>9.7,"Grade"] #loc[index,colnames]
#accessing the records with sem3>9.7 but printing only grade column
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
#print the grades  of students who scored more than 9.7 in sem3
mydf2.loc[mydf2.SEM3>9.7,"Grade"] #loc[index,colnames]
#accessing the records with sem3>9.7 but printing only grade column
# Out:
# 0     A+
# 2      A
# 3      B
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
mydf2
# Out:
#      Names Initials        SEM1  SEM2        SEM3 Grade  Placed
# 0      Joe        K    9.800000  10.0    9.900000    A+       1
# 1   Rajesh        M    8.900000   9.1    9.300000     A       1
# 2   Kissan        V    9.900000   9.8   10.000000     A       0
# 3     Mary        N    7.700000   8.0  105.347059     B       0
# 4     Jeen        K    9.800000   9.1    9.900000    A+       1
# 5      Raj        M    8.900000   9.1    9.300000     A       1
# 6   Hassan        V    9.900000   9.0    9.200000     A       1
# 7     Mari        N    7.700000   8.0    7.100000     B       1
# 8     Jess        K  105.347059   9.1    9.900000    A+       1
# 9   Rajini        M  105.347059   9.1    9.300000     A       0
# 10   Kiran        V  105.347059   9.3    9.200000     A       0
# 11    Maya        N    7.700000   8.0    7.100000     B       0
# 12   Jolin        K    9.800000   9.1    9.900000    A+       1
# 13  Rajesh        M    8.900000   9.1    9.300000     A       1
# ...

# %%
#accessing using index functions
print(mydf[mydf.index==7])   #for getting 7th record
print("Accessing specific row and column")
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# Accessing specific row and column
# 7    B
# Name: Grade, dtype: object

# %%
mydf.drop_duplicates(inplace=True)   #cleaning technique
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
mydf.drop_duplicates()  #for  viewing the data frame
print(mydf)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
mydf.drop_duplicates(inplace=True)   #for saving and removung duplicate values
print(mydf)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
mydf.head()   #by default displays top 5 records
mydf.head(7)    #displays top 7 records
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1
# 6  Hassan        V   9.9   9.0   9.200000     A       1

# %%
mydf.tail()   #by default displays last 5 records
mydf.tail(7)    #displays last 7 records
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 11    Maya        N  7.700000   8.0   7.1     B       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 14    Riya        M  9.300000   9.9  10.0     A       1
# 15    Sana        V  9.900000   9.3   9.2     A       0
# 16    Mark        N  7.700000   8.0   7.0     B       0

# %%
#accessing using index functions
mydf[mydf.index==7]   #for getting 7th record
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1

# %%
#columns!
col=mydf.columns  #view and save column names
print(col)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#columns!
collist=list(mydf.columns)  #view and save column names
print(collist)    #it changes the list
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#rename a column
mydf.rename(columns={'Grade':'GPA'},inplace=True)
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed'], dtype='object')

# %%
#creating a new column!  or #accessing a new coulumn!
#dfname['new col']=values
mydf["Conduct"]="Good"
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 GPA  Placed Conduct
# 0      Joe        K  9.800000  10.0   9.900000  A+       1    Good
# 1   Rajesh        M  8.900000   9.1   9.300000   A       1    Good
# 2   Kissan        V  9.900000   9.8  10.000000   A       0    Good
# 3     Mary        N  7.700000   8.0   8.992857   B       0    Good
# 4     Jeen        K  9.800000   9.1   9.900000  A+       1    Good
# 5      Raj        M  8.900000   9.1   9.300000   A       1    Good
# 6   Hassan        V  9.900000   9.0   9.200000   A       1    Good
# 7     Mari        N  7.700000   8.0   7.100000   B       1    Good
# 8     Jess        K  8.992857   9.1   9.900000  A+       1    Good
# 9   Rajini        M  8.992857   9.1   9.300000   A       0    Good
# 10   Kiran        V  8.992857   9.3   9.200000   A       0    Good
# 11    Maya        N  7.700000   8.0   7.100000   B       0    Good
# 12   Jolin        K  9.800000   9.1   9.900000  A+       1    Good
# ...

# %%
#create a new column average with average values of sem-1,2,3
#creating a new column!
#dfname['new col']=values
mydf["Conduct"] = "Good"
mydf["Average"] = (mydf["SEM1"] + mydf["SEM2"] + mydf["SEM3"]) / 3
mydf
# Out:
#      Names Initials      SEM1  SEM2       SEM3 GPA  Placed Conduct   Average
# 0      Joe        K  9.800000  10.0   9.900000  A+       1    Good  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000   A       1    Good  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000   A       0    Good  9.900000
# 3     Mary        N  7.700000   8.0   8.992857   B       0    Good  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000  A+       1    Good  9.600000
# 5      Raj        M  8.900000   9.1   9.300000   A       1    Good  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000   A       1    Good  9.366667
# 7     Mari        N  7.700000   8.0   7.100000   B       1    Good  7.600000
# 8     Jess        K  8.992857   9.1   9.900000  A+       1    Good  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000   A       0    Good  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000   A       0    Good  9.164286
# ...

# %% [markdown]
# # DATA VISUALISATION USING PANDAS

# %%
#PLOTTING WITH PANDAS
mydf['SEM1'].plot.line()    #dFname['col'].plot.line()
# Out:
# <Axes: >

# %%
mydf[["SEM1","SEM2"]].plot.line() #plotting multiple columns
# Out:
# <Axes: >

# %%
mydf[['SEM1','SEM2']].plot.line(subplots=True)   #plotting multiple columns  #dfname['col','col'].plot.line()
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf[['SEM1','SEM2','SEM3']].plot.line(subplots=True)  #plotting multiple columns  #dfname['col','col'].plot.line()
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot(kind="scatter",x="Average",y="Names")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
mydf.plot(kind="hist",x="Names",y="Average")  #y-axis-numeric
                                              #x-axis-count
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf.plot(kind='hist',x='Names',y='Average')  #y should be numeric
#kind='Scatter'(dots)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("mydata.csv")
