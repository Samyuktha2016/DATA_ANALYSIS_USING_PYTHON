# %%
import pandas as pd

# %%
df=pd.read_csv("/content/mydata (1).csv")
df
# Out:
#     Unnamed: 0   Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0            0     Joe        K  9.800000  10.0   9.900000    A+       1
# 1            1  Rajesh        M  8.900000   9.1   9.300000     A       1
# 2            2  Kissan        V  9.900000   9.8  10.000000     A       0
# 3            3    Mary        N  7.700000   8.0   8.992857     B       0
# 4            4    Jeen        K  9.800000   9.1   9.900000    A+       1
# 5            5     Raj        M  8.900000   9.1   9.300000     A       1
# 6            6  Hassan        V  9.900000   9.0   9.200000     A       1
# 7            7    Mari        N  7.700000   8.0   7.100000     B       1
# 8            8    Jess        K  8.992857   9.1   9.900000    A+       1
# 9            9  Rajini        M  8.992857   9.1   9.300000     A       0
# 10          10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11          11    Maya        N  7.700000   8.0   7.100000     B       0
# ...

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=df)

# %%
#relplot
sns.relplot(data=df,x="SEM1",y="Names",col="Placed")
#col==> Graphs are seperated based on this column

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")
dfe.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
#create a relational plot using age as y axis index as x axis seperated by class
#diabeties.xlsx
dfe['Index']=range(1,769)
dfe
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
#create a relational plot using age as y-axis ,index as x-axis,seperated by class
sns.relplot(data=dfe,x="Index",y="age",col="class")

# %%
tips=sns.load_dataset("tips")
tips.tail(50)   #for lunch
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 194       16.58  4.00    Male    Yes  Thur   Lunch     2
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4
# 208       24.27  2.03    Male    Yes   Sat  Dinner     2
# ...

# %%
sns.load_dataset("tips")
 #loading datasets in seaborn  #syntax---->to load dataset use:load_dataset("Data set name")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker")
#hue-creating difference based on a column via colors

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="bright")
#hue - creating a differnce based on a column via colors

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="bright")
#hue-creating difference based on a column via colors hue-- color changing  style---marker   palette---for bright ,light ,etc different types

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="size",style="time",palette="bright")
#hue - creating a differnce based on a column via colors

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="size",palette="bright")
#hue-creating difference based on a column via colors hue-- color changing  style---marker   palette---for bright ,light ,etc different types ,size for how many members are there

# %%
sns.load_dataset("dowjones")
dowjones=sns.load_dataset("dowjones")
 #loading datasets in seaborn  #syntax---->to load dataset use:load_dataset("Data set name")

# %%
sns.relplot(data=dowjones,x='Date',y='Price',kind='line')

# %%
fmri=sns.load_dataset("fmri")
fmri
 #loading datasets in seaborn  #syntax---->to load dataset use:load_dataset("Data set name")
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri,x='timepoint',y='signal',kind='line')

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %%
#catplot-catagory wise plot based on y
sns.catplot(data=fmri,x="timepoint",y="signal")

# %%
sns.catplot(data=tips,x="total_bill",y='day')

# %%
sns.catplot(data=tips,x="total_bill",y='smoker')

# %%
sns.catplot(data=tips,y="total_bill",x="time",hue="smoker",kind="violin")

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="box",hue="smoker")

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="box")
