# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/rnn .txt',sep=',')
df
# Out:
# Empty DataFrame
# Columns: [Earth is the third planet from the Sun and the only astronomical object known to harbor life. This is enabled by Earth being a water world,  the only one in the Solar System sustaining liquid surface water. Almost all of Earth's water is contained in its global ocean,  covering 70.8% of Earth's crust. The remaining 29.2% of Earth's crust is land,  most of which is located in the form of continental landmasses within one hemisphere,  Earth's land hemisphere. Most of Earth's land is somewhat humid and covered by vegetation,  while large sheets of ice at Earth's polar deserts retain more water than Earth's groundwater,  lakes,  rivers and atmospheric water combined. Earth's crust consists of slowly moving tectonic plates,  which interact to produce mountain ranges,  volcanoes,  and earthquakes. Earth has a liquid outer core that generates a magnetosphere capable of deflecting most of the destructive solar winds and cosmic radiation.]
# Index: []

# %%
#Tokenizing the words
tokenizer= Tokenizer()
tokenizer.fit_on_texts(df)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 95

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in df:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[7, 4],
#  [7, 4, 2],
#  [7, 4, 2, 21],
#  [7, 4, 2, 21, 22],
#  [7, 4, 2, 21, 22, 23],
#  [7, 4, 2, 21, 22, 23, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4, 31],
#  [7, 4, 2, 21, 22, 23, 2, 24, 5, 2, 13, 25, 26, 27, 14, 28, 29, 30, 4, 31, 15],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8,
#   6],
#  [7,
#   4,
#   2,
#   21,
#   22,
#   23,
#   2,
#   24,
#   5,
#   2,
#   13,
#   25,
#   26,
#   27,
#   14,
#   28,
#   29,
#   30,
#   4,
#   31,
#   15,
#   7,
#   32,
#   8,
#   6,
#   33],
#  [2, 13],
#  [2, 13, 16],
#  [2, 13, 16, 9],
#  [2, 13, 16, 9, 2],
#  [2, 13, 16, 9, 2, 17],
#  [2, 13, 16, 9, 2, 17, 34],
#  [2, 13, 16, 9, 2, 17, 34, 35],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9, 40],
#  [2, 13, 16, 9, 2, 17, 34, 35, 18, 36, 6, 37, 38, 1, 3, 6, 4, 39, 9, 40, 41],
#  [2,
#   13,
#   16,
#   9,
#   2,
#   17,
#   34,
#   35,
#   18,
#   36,
#   6,
#   37,
#   38,
#   1,
#   3,
#   6,
#   4,
#   39,
#   9,
#   40,
#   41,
#   42],
#  [43, 44],
#  [43, 44, 45],
#  [43, 44, 45, 1],
#  [43, 44, 45, 1, 3],
#  [43, 44, 45, 1, 3, 10],
#  [43, 44, 45, 1, 3, 10, 2],
#  [43, 44, 45, 1, 3, 10, 2, 46],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10, 4],
#  [43, 44, 45, 1, 3, 10, 2, 46, 47, 48, 1, 3, 10, 4, 11],
#  [12, 1],
#  [12, 1, 19],
#  [12, 1, 19, 4],
#  [12, 1, 19, 4, 49],
#  [12, 1, 19, 4, 49, 9],
#  [12, 1, 19, 4, 49, 9, 2],
#  [12, 1, 19, 4, 49, 9, 2, 50],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16],
#  [12, 1, 19, 4, 49, 9, 2, 50, 1, 51, 52, 53, 16, 20],
#  [3, 11],
#  [3, 11, 20],
#  [3, 11, 20, 12],
#  [3, 11, 20, 12, 1],
#  [3, 11, 20, 12, 1, 3],
#  [3, 11, 20, 12, 1, 3, 11],
#  [3, 11, 20, 12, 1, 3, 11, 4],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56, 15],
#  [3, 11, 20, 12, 1, 3, 11, 4, 54, 55, 5, 56, 15, 57],
#  [58, 59],
#  [58, 59, 60],
#  [58, 59, 60, 1],
#  [58, 59, 60, 1, 61],
#  [58, 59, 60, 1, 61, 62],
#  [58, 59, 60, 1, 61, 62, 3],
#  [58, 59, 60, 1, 61, 62, 3, 63],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67, 3],
#  [58, 59, 60, 1, 61, 62, 3, 63, 64, 65, 66, 6, 67, 3, 68],
#  [70, 5],
#  [70, 5, 71],
#  [70, 5, 71, 6],
#  [70, 5, 71, 6, 72],
#  [70, 5, 71, 6, 72, 3],
#  [70, 5, 71, 6, 72, 3, 10],
#  [70, 5, 71, 6, 72, 3, 10, 73],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75, 76],
#  [70, 5, 71, 6, 72, 3, 10, 73, 1, 74, 75, 76, 77],
#  [19, 78],
#  [19, 78, 14],
#  [19, 78, 14, 79],
#  [19, 78, 14, 79, 80],
#  [19, 78, 14, 79, 80, 81],
#  [5, 83],
#  [5, 83, 7],
#  [5, 83, 7, 84],
#  [5, 83, 7, 84, 8],
#  [5, 83, 7, 84, 8, 18],
#  [5, 83, 7, 84, 8, 18, 85],
#  [5, 83, 7, 84, 8, 18, 85, 86],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17],
#  [5, 83, 7, 84, 8, 18, 85, 86, 87, 88, 8, 89, 90, 1, 91, 12, 1, 2, 92, 17, 93],
#  [5,
#   83,
#   7,
#   84,
#   8,
#   18,
#   85,
#   86,
#   87,
#   88,
#   8,
#   89,
#   90,
#   1,
#   91,
#   12,
#   1,
#   2,
#   92,
#   17,
#   93,
#   5],
#  [5,
#   83,
#   7,
#   84,
#   8,
#   18,
#   85,
#   86,
#   87,
#   88,
#   8,
#   89,
#   90,
#   1,
#   91,
#   12,
#   1,
#   2,
#   92,
#   17,
#   93,
#   5,
#   94]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length,padding='pre')
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  7,  4],
#        [ 0,  0,  0, ...,  7,  4,  2],
#        [ 0,  0,  0, ...,  4,  2, 21],
#        ...,
#        [ 0,  0,  0, ..., 92, 17, 93],
#        [ 0,  0,  0, ..., 17, 93,  5],
#        [ 0,  0,  0, ..., 93,  5, 94]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
#compiling the model
model.compile(optimizer='adam',loss='categorical_crossentorpy',metrics=['accurary'])

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 3s - loss: 4.6034 - accuracy: 0.0144 - 3s/epoch - 560ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 4.3497 - accuracy: 0.1151 - 77ms/epoch - 15ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 4.1862 - accuracy: 0.1655 - 77ms/epoch - 15ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 4.0365 - accuracy: 0.1871 - 97ms/epoch - 19ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.9113 - accuracy: 0.2230 - 297ms/epoch - 59ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.7603 - accuracy: 0.2374 - 347ms/epoch - 69ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 3.6254 - accuracy: 0.3165 - 341ms/epoch - 68ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 3.4807 - accuracy: 0.3741 - 353ms/epoch - 71ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 3.3389 - accuracy: 0.3813 - 400ms/epoch - 80ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 3.1951 - accuracy: 0.4460 - 389ms/epoch - 78ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 3.0520 - accuracy: 0.4676 - 258ms/epoch - 52ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.9094 - accuracy: 0.5180 - 357ms/epoch - 71ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.7764 - accuracy: 0.5396 - 327ms/epoch - 65ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.6388 - accuracy: 0.6115 - 317ms/epoch - 63ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.5250 - accuracy: 0.5755 - 162ms/epoch - 32ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.3752 - accuracy: 0.6187 - 187ms/epoch - 37ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 2.2700 - accuracy: 0.6475 - 219ms/epoch - 44ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 2.1306 - accuracy: 0.6835 - 175ms/epoch - 35ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 2.0219 - accuracy: 0.6906 - 235ms/epoch - 47ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.8926 - accuracy: 0.6978 - 207ms/epoch - 41ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.7811 - accuracy: 0.7122 - 206ms/epoch - 41ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.6975 - accuracy: 0.7338 - 190ms/epoch - 38ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5993 - accuracy: 0.7338 - 164ms/epoch - 33ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.5132 - accuracy: 0.7410 - 164ms/epoch - 33ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4396 - accuracy: 0.7626 - 142ms/epoch - 28ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3629 - accuracy: 0.7626 - 184ms/epoch - 37ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.2774 - accuracy: 0.7914 - 205ms/epoch - 41ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2502 - accuracy: 0.7986 - 146ms/epoch - 29ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.1671 - accuracy: 0.7986 - 162ms/epoch - 32ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.1028 - accuracy: 0.8273 - 158ms/epoch - 32ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.0404 - accuracy: 0.8417 - 152ms/epoch - 30ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 1.0033 - accuracy: 0.8417 - 122ms/epoch - 24ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.9480 - accuracy: 0.8561 - 86ms/epoch - 17ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.9101 - accuracy: 0.8489 - 76ms/epoch - 15ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.8382 - accuracy: 0.8705 - 76ms/epoch - 15ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.8180 - accuracy: 0.8777 - 79ms/epoch - 16ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.7652 - accuracy: 0.8705 - 76ms/epoch - 15ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.7397 - accuracy: 0.8921 - 88ms/epoch - 18ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6904 - accuracy: 0.8993 - 76ms/epoch - 15ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.6602 - accuracy: 0.9137 - 74ms/epoch - 15ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.6251 - accuracy: 0.9353 - 74ms/epoch - 15ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.5977 - accuracy: 0.9353 - 76ms/epoch - 15ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5776 - accuracy: 0.8921 - 79ms/epoch - 16ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5525 - accuracy: 0.9065 - 82ms/epoch - 16ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5287 - accuracy: 0.9353 - 78ms/epoch - 16ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.5014 - accuracy: 0.9353 - 78ms/epoch - 16ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.4750 - accuracy: 0.9496 - 79ms/epoch - 16ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4622 - accuracy: 0.9496 - 79ms/epoch - 16ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4467 - accuracy: 0.9496 - 75ms/epoch - 15ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4346 - accuracy: 0.9424 - 84ms/epoch - 17ms/step

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X,y,epochs=50,verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 2s - loss: 4.5746 - accuracy: 0.0288 - 2s/epoch - 478ms/step
# Epoch 2/50
# 5/5 - 0s - loss: 4.3694 - accuracy: 0.0504 - 80ms/epoch - 16ms/step
# Epoch 3/50
# 5/5 - 0s - loss: 4.1605 - accuracy: 0.1079 - 91ms/epoch - 18ms/step
# Epoch 4/50
# 5/5 - 0s - loss: 4.0232 - accuracy: 0.1871 - 80ms/epoch - 16ms/step
# Epoch 5/50
# 5/5 - 0s - loss: 3.9075 - accuracy: 0.2014 - 80ms/epoch - 16ms/step
# Epoch 6/50
# 5/5 - 0s - loss: 3.7474 - accuracy: 0.2950 - 75ms/epoch - 15ms/step
# Epoch 7/50
# 5/5 - 0s - loss: 3.6148 - accuracy: 0.3309 - 78ms/epoch - 16ms/step
# Epoch 8/50
# 5/5 - 0s - loss: 3.4542 - accuracy: 0.3525 - 76ms/epoch - 15ms/step
# Epoch 9/50
# 5/5 - 0s - loss: 3.3304 - accuracy: 0.3669 - 77ms/epoch - 15ms/step
# Epoch 10/50
# 5/5 - 0s - loss: 3.1681 - accuracy: 0.4101 - 79ms/epoch - 16ms/step
# Epoch 11/50
# 5/5 - 0s - loss: 3.0209 - accuracy: 0.4892 - 77ms/epoch - 15ms/step
# Epoch 12/50
# 5/5 - 0s - loss: 2.8871 - accuracy: 0.5036 - 76ms/epoch - 15ms/step
# Epoch 13/50
# 5/5 - 0s - loss: 2.7427 - accuracy: 0.5612 - 77ms/epoch - 15ms/step
# Epoch 14/50
# 5/5 - 0s - loss: 2.6187 - accuracy: 0.5971 - 77ms/epoch - 15ms/step
# Epoch 15/50
# 5/5 - 0s - loss: 2.4741 - accuracy: 0.6403 - 99ms/epoch - 20ms/step
# Epoch 16/50
# 5/5 - 0s - loss: 2.3694 - accuracy: 0.6763 - 75ms/epoch - 15ms/step
# Epoch 17/50
# 5/5 - 0s - loss: 2.2414 - accuracy: 0.6547 - 83ms/epoch - 17ms/step
# Epoch 18/50
# 5/5 - 0s - loss: 2.1144 - accuracy: 0.7050 - 76ms/epoch - 15ms/step
# Epoch 19/50
# 5/5 - 0s - loss: 2.0099 - accuracy: 0.7194 - 81ms/epoch - 16ms/step
# Epoch 20/50
# 5/5 - 0s - loss: 1.8992 - accuracy: 0.7338 - 78ms/epoch - 16ms/step
# Epoch 21/50
# 5/5 - 0s - loss: 1.7907 - accuracy: 0.7410 - 77ms/epoch - 15ms/step
# Epoch 22/50
# 5/5 - 0s - loss: 1.6729 - accuracy: 0.7626 - 77ms/epoch - 15ms/step
# Epoch 23/50
# 5/5 - 0s - loss: 1.5929 - accuracy: 0.7482 - 75ms/epoch - 15ms/step
# Epoch 24/50
# 5/5 - 0s - loss: 1.5214 - accuracy: 0.7410 - 80ms/epoch - 16ms/step
# Epoch 25/50
# 5/5 - 0s - loss: 1.4643 - accuracy: 0.7770 - 75ms/epoch - 15ms/step
# Epoch 26/50
# 5/5 - 0s - loss: 1.3320 - accuracy: 0.7914 - 77ms/epoch - 15ms/step
# Epoch 27/50
# 5/5 - 0s - loss: 1.2665 - accuracy: 0.7986 - 79ms/epoch - 16ms/step
# Epoch 28/50
# 5/5 - 0s - loss: 1.2102 - accuracy: 0.7986 - 89ms/epoch - 18ms/step
# Epoch 29/50
# 5/5 - 0s - loss: 1.1363 - accuracy: 0.8129 - 88ms/epoch - 18ms/step
# Epoch 30/50
# 5/5 - 0s - loss: 1.0679 - accuracy: 0.8273 - 76ms/epoch - 15ms/step
# Epoch 31/50
# 5/5 - 0s - loss: 1.0314 - accuracy: 0.8273 - 77ms/epoch - 15ms/step
# Epoch 32/50
# 5/5 - 0s - loss: 0.9635 - accuracy: 0.8345 - 78ms/epoch - 16ms/step
# Epoch 33/50
# 5/5 - 0s - loss: 0.9113 - accuracy: 0.8705 - 83ms/epoch - 17ms/step
# Epoch 34/50
# 5/5 - 0s - loss: 0.8696 - accuracy: 0.8705 - 82ms/epoch - 16ms/step
# Epoch 35/50
# 5/5 - 0s - loss: 0.8276 - accuracy: 0.8921 - 77ms/epoch - 15ms/step
# Epoch 36/50
# 5/5 - 0s - loss: 0.8010 - accuracy: 0.8561 - 113ms/epoch - 23ms/step
# Epoch 37/50
# 5/5 - 0s - loss: 0.7725 - accuracy: 0.8777 - 151ms/epoch - 30ms/step
# Epoch 38/50
# 5/5 - 0s - loss: 0.7280 - accuracy: 0.8777 - 157ms/epoch - 31ms/step
# Epoch 39/50
# 5/5 - 0s - loss: 0.6922 - accuracy: 0.8849 - 154ms/epoch - 31ms/step
# Epoch 40/50
# 5/5 - 0s - loss: 0.6542 - accuracy: 0.9137 - 158ms/epoch - 32ms/step
# Epoch 41/50
# 5/5 - 0s - loss: 0.6320 - accuracy: 0.8993 - 199ms/epoch - 40ms/step
# Epoch 42/50
# 5/5 - 0s - loss: 0.6091 - accuracy: 0.8993 - 132ms/epoch - 26ms/step
# Epoch 43/50
# 5/5 - 0s - loss: 0.5842 - accuracy: 0.8993 - 80ms/epoch - 16ms/step
# Epoch 44/50
# 5/5 - 0s - loss: 0.5752 - accuracy: 0.9137 - 77ms/epoch - 15ms/step
# Epoch 45/50
# 5/5 - 0s - loss: 0.5574 - accuracy: 0.9137 - 83ms/epoch - 17ms/step
# Epoch 46/50
# 5/5 - 0s - loss: 0.5188 - accuracy: 0.9137 - 90ms/epoch - 18ms/step
# Epoch 47/50
# 5/5 - 0s - loss: 0.5010 - accuracy: 0.9137 - 79ms/epoch - 16ms/step
# Epoch 48/50
# 5/5 - 0s - loss: 0.4802 - accuracy: 0.9209 - 76ms/epoch - 15ms/step
# Epoch 49/50
# 5/5 - 0s - loss: 0.4670 - accuracy: 0.9424 - 81ms/epoch - 16ms/step
# Epoch 50/50
# 5/5 - 0s - loss: 0.4498 - accuracy: 0.9496 - 75ms/epoch - 15ms/step

# %%
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: Earth
# Enter how many words to predict: 4
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Earth is the third planet
